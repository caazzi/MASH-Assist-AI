# %%
# --- STEP ZERO: NETWORK CONFIGURATION FOR WSL ---
import os
os.environ["GRPC_DNS_RESOLVER"] = "native"
# --- END OF NETWORK CONFIGURATION ---

from dotenv import load_dotenv
import time
import langchain

# Load environment variables from the .env file
load_dotenv()

# Check if the Google API key was loaded
if 'GOOGLE_API_KEY' not in os.environ:
    print("Error: Google API Key not found. Check your .env file.")
else:
    print("Google API Key loaded successfully.")

# --- Imports for AI libraries ---
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_google_genai import GoogleGenerativeAI
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# --- STEP 3.3.3: CREATE OR LOAD THE VECTOR STORE ---
# Define the path for the saved FAISS index
FAISS_INDEX_PATH = "faiss_index"

# Define the embedding model to be used.
model_name = "sentence-transformers/all-MiniLM-L6-v2"
model_kwargs = {'device': 'cpu'} # Use 'cuda' if you have a configured GPU
encode_kwargs = {'normalize_embeddings': False}
embeddings = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

# Check if the vector store already exists
if os.path.exists(FAISS_INDEX_PATH):
    print("Loading existing vector store from disk...")
    # allow_dangerous_deserialization is needed for loading local FAISS indexes
    vectorstore = FAISS.load_local(FAISS_INDEX_PATH, embeddings, allow_dangerous_deserialization=True)
    print("Vector store loaded successfully!")
else:
    print("No existing vector store found. Creating a new one...")
    # --- STEP 3.3.1: LOAD THE KNOWLEDGE BASE ---
    loader = DirectoryLoader('./knowledge_base/', glob="./*.pdf", loader_cls=PyPDFLoader)
    documents = loader.load()
    print(f"Total documents loaded: {len(documents)}")

    # --- STEP 3.3.2: SPLIT DOCUMENTS INTO CHUNKS ---
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150)
    texts = text_splitter.split_documents(documents)
    print(f"Total text chunks created: {len(texts)}")

    # Create the FAISS vector store from the text chunks and the embedding model.
    print("\nCreating embeddings and vector store... This might take a moment.")
    vectorstore = FAISS.from_documents(texts, embeddings)
    print("Vector store created successfully!")

    # Save the vector store to disk for future use
    vectorstore.save_local(FAISS_INDEX_PATH)
    print(f"Vector store saved to disk at: {FAISS_INDEX_PATH}")


# --- STEP 3.3.4: CONFIGURE THE LLM AND THE RETRIEVAL CHAIN ---
# Configure the LLM that will be used to generate answers
llm = GoogleGenerativeAI(model="gemini-1.0-pro", temperature=0.3)

# Create a prompt template to instruct the LLM on how to behave
prompt_template = """
Use the following context to answer the question in a detailed and precise manner.
If the answer is not in the context, say "The information is not available in my knowledge base."

Context:
{context}

Question:
{question}

Answer:
"""
PROMPT = PromptTemplate(template=prompt_template, input_variables=["context", "question"])

# Create the Retrieval Question-Answering chain
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever(search_kwargs={"k": 3}), # Retrieve the 3 most relevant chunks
    return_source_documents=True,
    chain_type_kwargs={"prompt": PROMPT}
)

# --- STEP 3.3.5: TESTING THE SYSTEM ---
print("\n--- Testing the AI Assistant ---")

# Now you can ask questions directly without debug mode for a cleaner output
question1 = "What are the main challenges in MASH diagnosis?"
print(f"\nQuestion: {question1}")
response1 = qa_chain.invoke({"query": question1})
print(f"Answer: {response1['result']}\n")

question2 = "What is the FIB-4 score?"
print(f"Question: {question2}")
response2 = qa_chain.invoke({"query": question2})
print(f"Answer: {response2['result']}\n")

question3 = "What is the prevalence of MASH in Latin America?"
print(f"Question: {question3}")
response3 = qa_chain.invoke({"query": question3})
print(f"Answer: {response3['result']}\n")
# Out:
# Google API Key loaded successfully.
# Ignoring wrong pointing object 11 0 (offset 0)
# Total documents loaded: 127
# Total text chunks created: 959
#
# Creating the vector store... This might take a moment.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 53
#      50 # Create the FAISS vector store from the text chunks and the embedding model.
#      51 # This step may take a few minutes the first time.
#      52 print("\nCreating the vector store... This might take a moment.")
# ---> 53 vectorstore = FAISS.from_documents(texts, embeddings)
#      54 print("Vector store created successfully!")
#      56 # --- STEP 3.3.4: CONFIGURE THE LLM AND THE RETRIEVAL CHAIN ---
#      57 # Configure the LLM that will be used to generate answers
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/langchain_core/vectorstores/base.py:848, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     845     if any(ids):
#     846         kwargs["ids"] = ids
# --> 848 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/langchain_community/vectorstores/faiss.py:1043, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1016 @classmethod
#    1017 def from_texts(
#    1018     cls,
#    (...)
#    1023     **kwargs: Any,
#    1024 ) -> FAISS:
#    1025     """Construct FAISS wrapper from raw documents.
#    1026
#    1027     This is a user friendly interface that:
#    (...)
#    1041             faiss = FAISS.from_texts(texts, embeddings)
#    1042     """
# -> 1043     embeddings = embedding.embed_documents(texts)
#    1044     return cls.__from(
#    1045         texts,
#    1046         embeddings,
#    (...)
#    1050         **kwargs,
#    1051     )
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/langchain_community/embeddings/huggingface.py:115, in HuggingFaceEmbeddings.embed_documents(self, texts)
#     113     sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#     114 else:
# --> 115     embeddings = self.client.encode(
#     116         texts, show_progress_bar=self.show_progress, **self.encode_kwargs
#     117     )
#     119 return embeddings.tolist()
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:1051, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1048 features.update(extra_features)
#    1050 with torch.no_grad():
# -> 1051     out_features = self.forward(features, **kwargs)
#    1052     if self.device.type == "hpu":
#    1053         out_features = copy.deepcopy(out_features)
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:1132, in SentenceTransformer.forward(self, input, **kwargs)
#    1126             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1127         module_kwargs = {
#    1128             key: value
#    1129             for key, value in kwargs.items()
#    1130             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1131         }
# -> 1132     input = module(input, **module_kwargs)
#    1133 return input
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/sentence_transformers/models/Transformer.py:234, in Transformer.forward(self, features, **kwargs)
#     227 """Returns token_embeddings, cls_token"""
#     228 trans_features = {
#     229     key: value
#     230     for key, value in features.items()
#     231     if key in ["input_ids", "attention_mask", "token_type_ids", "inputs_embeds"]
#     232 }
# --> 234 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     235 token_embeddings = outputs[0]
#     236 features["token_embeddings"] = token_embeddings
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:1006, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     999 # Prepare head mask if needed
#    1000 # 1.0 in head_mask indicate we keep the head
#    1001 # attention_probs has shape bsz x n_heads x N x N
#    1002 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1003 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1004 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1006 encoder_outputs = self.encoder(
#    1007     embedding_output,
#    1008     attention_mask=extended_attention_mask,
#    1009     head_mask=head_mask,
#    1010     encoder_hidden_states=encoder_hidden_states,
#    1011     encoder_attention_mask=encoder_extended_attention_mask,
#    1012     past_key_values=past_key_values,
#    1013     use_cache=use_cache,
#    1014     output_attentions=output_attentions,
#    1015     output_hidden_states=output_hidden_states,
#    1016     return_dict=return_dict,
#    1017     cache_position=cache_position,
#    1018 )
#    1019 sequence_output = encoder_outputs[0]
#    1020 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:653, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     649     all_hidden_states = all_hidden_states + (hidden_states,)
#     651 layer_head_mask = head_mask[i] if head_mask is not None else None
# --> 653 layer_outputs = layer_module(
#     654     hidden_states,
#     655     attention_mask,
#     656     layer_head_mask,
#     657     encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     658     encoder_attention_mask=encoder_attention_mask,
#     659     past_key_value=past_key_values,
#     660     output_attentions=output_attentions,
#     661     cache_position=cache_position,
#     662 )
#     664 hidden_states = layer_outputs[0]
#     665 if output_attentions:
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/transformers/modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:562, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions, cache_position)
#     551 def forward(
#     552     self,
#     553     hidden_states: torch.Tensor,
#    (...)
#     560     cache_position: Optional[torch.Tensor] = None,
#     561 ) -> tuple[torch.Tensor]:
# --> 562     self_attention_outputs = self.attention(
#     563         hidden_states,
#     564         attention_mask=attention_mask,
#     565         head_mask=head_mask,
#     566         output_attentions=output_attentions,
#     567         past_key_value=past_key_value,
#     568         cache_position=cache_position,
#     569     )
#     570     attention_output = self_attention_outputs[0]
#     571     outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:493, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, past_key_value, output_attentions, cache_position)
#     483 def forward(
#     484     self,
#     485     hidden_states: torch.Tensor,
#    (...)
#     491     cache_position: Optional[torch.Tensor] = None,
#     492 ) -> tuple[torch.Tensor]:
# --> 493     self_outputs = self.self(
#     494         hidden_states,
#     495         attention_mask=attention_mask,
#     496         head_mask=head_mask,
#     497         encoder_hidden_states=encoder_hidden_states,
#     498         past_key_value=past_key_value,
#     499         output_attentions=output_attentions,
#     500         cache_position=cache_position,
#     501     )
#     502     attention_output = self.output(self_outputs[0], hidden_states)
#     503     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:390, in BertSdpaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, past_key_value, output_attentions, cache_position)
#     383 else:
#     384     key_layer = (
#     385         self.key(current_states)
#     386         .view(bsz, -1, self.num_attention_heads, self.attention_head_size)
#     387         .transpose(1, 2)
#     388     )
#     389     value_layer = (
# --> 390         self.value(current_states)
#     391         .view(bsz, -1, self.num_attention_heads, self.attention_head_size)
#     392         .transpose(1, 2)
#     393     )
#     395     if past_key_value is not None:
#     396         # save all key/value_layer to cache to be re-used for fast auto-regressive generation
#     397         cache_position = cache_position if not is_cross_attention else None
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/mash-assist-ai/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
